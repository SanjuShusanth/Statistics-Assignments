# %% [markdown]
# #### Q1. What is the Probability density function?

# %% [markdown]
# * Probability Density function it describes the distribution of continous random variable, The use of PDF is to find out the chances that the random variable will occur within the range of values that is specified.

# %% [markdown]
# #### Q2. What are the types of Probability distribution?

# %% [markdown]
# * Discrete Probability Distribution - It takes the finite number of values. eg - Binomial Distribution and Poison Distribution
#
# * Continous Probability Distribution - It can take any values within the range. eg - Normal or Gaussian Distribution

# %% [markdown]
# #### Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
def PDF(mean, std):
    x = np.linspace(130, 180, 10)
    pdf1 = norm.pdf(x, mean, std)
    plt.plot(x, pdf1)
    plt.show()

# %%
PDF(155,12)

# %% [markdown]
# #### Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# * Binomial distribution represents the Probability Mass Function with the Discrete random varaible.
#
# * It provide the two possible outcomes either success or Failure per trial.
#
# * It denotes that p is the probability of success for every trail and 1-p is the probablity of Failure for every trial.
#
# * Each trial is independent.

# %% [markdown]
# #### Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

sample_size = 1000
prob = 0.4

sample = np.random.binomial(1,prob, size=sample_size)

plt.hist(sample, bins=2, edgecolor='black')
# Out:
# (array([594., 406.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# #### Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
from scipy.stats import poisson

def CDF(mean, point):
    cdf = poisson.cdf(point, mean)
    return cdf

# %%
CDF(5,3)
# Out:
# 0.2650259152973615

# %% [markdown]
# #### Q7. How Binomial distribution different from Poisson distribution

# %% [markdown]
# Binomial Distribution:
#
# * Binomial distribution describes the number of success in the fixed number of trials.
#
# * The parameters of the binomial distribution are number of trials and probability of success in each trial.
#
# Possion Distribution:
#
# * Poission Distribution describes the number of events occur at every interval.
#
# * The parameter of Possion distribution are average number of events occuring in the given interval, which we called it as Lambda.

# %% [markdown]
# #### Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
import numpy as np
import random 

sample_size= 1000
mean= 5

poison_d = np.random.poisson(lam=mean, size=sample_size)

Sample_mean = np.mean(poison_d)
Sample_Variance = np.var(poison_d)

print(Sample_mean,'\n',Sample_Variance)
# Out:
# 5.009
#  4.706919

# %% [markdown]
# #### Q9. How mean and variance are related in Binomial distribution and Poisson distribution

# %% [markdown]
# * For both Binomial and Poission Distribution mean and variance helps to find the central tendancy and amount of spread or disperssion that has happenned arround mean.

# %% [markdown]
# #### Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In Normal Distribution all the values will be concentrated more arround the mean, we can find the less frequency of data points lie in the tail of the distibution.
